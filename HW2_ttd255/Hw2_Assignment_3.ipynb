# %%
import os
from pandas import Series, DataFrame
import pandas
import pandas as pd
#import seaborn
import pylab as pl
import matplotlib
# %pylab inline
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib

# %%
DFDATA
# Out:
# '/gws/open/NYCOpenData/nycopendata/data'

# %%
df = pd.read_csv(DFDATA+'/uedp-fegm/1414245967/uedp-fegm')

# %%
df[:10]
# Out:
#                                          Zip Code  \
# 0  10001\n(40.75025902143676, -73.99688630375988)
# 1  10002\n(40.71612146793143, -73.98583147024613)
# 2  10003\n(40.73194394755518, -73.98887214913032)
# 3   10005\n(40.7061257920717, -74.00858468583453)
# 4  10006\n(40.70825614030866, -74.01355356964149)
# 5  10007\n(40.71363051943297, -74.00913138370635)
# 6  10009\n(40.72664935898081, -73.97911148500697)
# 7  10010\n(40.73914078212147, -73.98289845639863)
# 8  10011\n(40.74471526669623, -74.00460000028977)
# 9  10012\n(40.72553802086304, -73.99789641059084)
#
#   Building type (service class   Consumption (therms)    Consumption (GJ)   \
# 0                  Residential                 58338.0              6155.0
# 1                  Residential                550055.0             58034.0
# 2                  Residential                260502.0             27484.0
# 3                  Residential                   265.0                28.0
# ...

# %%
df_reducted = df.drop(['Zip Code','Building type (service class','Utility/Data Source'], axis =1)

# %%
df.columns
# Out:
# Index(['Zip Code', 'Building type (service class', ' Consumption (therms) ',
#        ' Consumption (GJ) ', 'Utility/Data Source'],
#       dtype='object')

# %%
df_reducted
# Out:
#        Consumption (therms)    Consumption (GJ)
# 0                    58338.0              6155.0
# 1                   550055.0             58034.0
# 2                   260502.0             27484.0
# 3                      265.0                28.0
# 4                     2076.0               219.0
# 5                    12845.0              1355.0
# 6                   186224.0             19648.0
# 7                    61263.0              6464.0
# 8                   192654.0             20326.0
# 9                   178497.0             18832.0
# 10                  228453.0             24103.0
# 11                  213234.0             22497.0
# 12                  111236.0             11736.0
# 13                   23970.0              2529.0
# 14                   21822.0              2302.0
# 15                  124706.0             13157.0
# 16                  185761.0             19599.0
# 17                  122395.0             12913.0
# ...

# %%
ax = df.plot.scatter(x=' Consumption (therms) ',y=' Consumption (GJ) ', alpha = 0.3)
ax.set_title('Natural Gas Consumption')
