# %%
import os
from pandas import Series, DataFrame
import pandas
import pandas as pd
#import seaborn
import pylab as pl
import matplotlib
import datetime
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
DFDATA = os.getenv('DFDATA')
print(DFDATA)
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
df = pd.read_csv(DFDATA+'/k46n-sa2m/1428334455/k46n-sa2m')

# %%
df[:10]
# Out:
#   Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0     04/05/2015                  33338.0                    23843.0
# 1     04/04/2015                  33236.0                    23798.0
# 2     04/03/2015                  33183.0                    23818.0
# 3     04/02/2015                  33227.0                    23820.0
# 4     04/01/2015                  33265.0                    23824.0
# 5     03/31/2015                  33339.0                    23827.0
# 6     03/30/2015                  33428.0                    23905.0
# 7     03/29/2015                  33427.0                    23903.0
# 8     03/28/2015                  33320.0                    23871.0
# 9     03/27/2015                  33384.0                    23919.0
#
#    Total Individuals in Shelter  Single Adult Men in Shelter  \
# 0                       57181.0                       8628.0
# 1                       57034.0                       8567.0
# ...

# %%
df.columns
# Out:
# Index(['Date of Census', 'Total Adults in Shelter',
#        'Total Children in Shelter', 'Total Individuals in Shelter',
#        'Single Adult Men in Shelter', 'Single Adult Women in Shelter',
#        'Total Single Adults in Shelter', 'Families with Children in Shelter',
#        'Adults in Families with Children in Shelter',
#        'Children in Families with Children in Shelter',
#        'Total Individuals in Families with Children in Shelter ',
#        'Adult Families in Shelter', 'Individuals in Adult Families in Shelter',
#        'Families Requesting Temporary Housing at PATH',
#        'Adult Families Requesting Temporary Housing at AFIC'],
#       dtype='object')

# %%
df_reducted = df.drop(['Total Children in Shelter', 'Total Individuals in Shelter',
       'Single Adult Men in Shelter', 'Single Adult Women in Shelter',
       'Total Single Adults in Shelter', 'Families with Children in Shelter',
       'Adults in Families with Children in Shelter',
       'Children in Families with Children in Shelter',
       'Total Individuals in Families with Children in Shelter ',
       'Adult Families in Shelter', 'Individuals in Adult Families in Shelter',
       'Families Requesting Temporary Housing at PATH',
       'Adult Families Requesting Temporary Housing at AFIC'], axis =1)

# %%
df_reducted
# Out:
#     Date of Census  Total Adults in Shelter
# 0       04/05/2015                  33338.0
# 1       04/04/2015                  33236.0
# 2       04/03/2015                  33183.0
# 3       04/02/2015                  33227.0
# 4       04/01/2015                  33265.0
# 5       03/31/2015                  33339.0
# 6       03/30/2015                  33428.0
# 7       03/29/2015                  33427.0
# 8       03/28/2015                  33320.0
# 9       03/27/2015                  33384.0
# 10      03/26/2015                  33437.0
# 11      03/25/2015                  33554.0
# 12      03/24/2015                  33520.0
# 13      03/23/2015                  33551.0
# 14      03/22/2015                  33563.0
# 15      03/21/2015                  33436.0
# 16      03/20/2015                  33508.0
# 17      03/19/2015                  33515.0
# 18      03/18/2015                  33568.0
# 19      03/17/2015                  33544.0
# ...

# %%
date = pd.to_datetime(df_reducted['Date of Census'])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xticklabels(date, rotation=45)
ax.plot_date(date,df_reducted['Total Adults in Shelter'])
ax.set_title('Number of Adults in Shelter by Date')
